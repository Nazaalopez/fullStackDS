# %%
# Imports
import pandas as pd
import os
import numpy as np

# %%
# Define the directory path
directory_path = '../../data/intermediate'

# List all files in the directory
files = [f for f in os.listdir(directory_path) if f.endswith('.csv') and f != 'data_dic.csv' and f != 'model_table.csv']

# Define the correct datatypes for pandas
dtypes = {
    'HCP_ID': 'str',
    'PATIENT_AGE': 'Int64',
    'PATIENT_GENDER': 'category',
    'PATIENT_ID': 'str',
    'STATE': 'category',
    'HCP_SPECIALTY': 'category',
    'HCP_AGE': 'Int64',
    'HCP_GENDER': 'category',
    'STATE_NAME': 'category',
    'TXN_LOCATION_TYPE': 'category',
    'INSURANCE_TYPE': 'category',
    'TXN_TYPE': 'category',
    'TXN_DESC': 'category'
}

# Specify the datetime columns
parse_dates = ['TXN_DT', 'BIRTH_DT']

# Load the CSV files into a dictionary of dataframes
dataframes = {}
for file in files:
    file_path = os.path.join(directory_path, file)
    
    # Read the CSV file without specifying parse_dates
    df = pd.read_csv(file_path, dtype=dtypes)
    
    # Check if 'TXN_DT' column exists and parse it as datetime if it does
    if 'TXN_DT' in df.columns:
        df['TXN_DT'] = pd.to_datetime(df['TXN_DT'])
    
    dataframes[file] = df

# Print the loaded dataframes
for file, df in dataframes.items():
    print(f"Data from {file}:")
    print(df.head())
# Out:
# Data from dim_physician.csv:
#   HCP_ID STATE        HCP_SPECIALTY  HCP_AGE HCP_GENDER  STATE_NAME
# 0      1    TX     PHYSICAL THERAPY     <NA>  U-Unknown       Texas
# 1      2    IN  PHYSICIAN ASSISTANT     <NA>  U-Unknown     Indiana
# 2      3    CA   EMERGENCY MEDICINE     <NA>  U-Unknown  California
# 3      4    TX   NURSE PRACTITIONER     <NA>  U-Unknown       Texas
# 4      5    WA   EMERGENCY MEDICINE     <NA>  U-Unknown  Washington
# Data from fact_txn.csv:
#       TXN_DT PATIENT_ID HCP_ID       TXN_LOCATION_TYPE INSURANCE_TYPE  \
# 0 2021-12-27       3124    NaN  INDEPENDENT LABORATORY     COMMERCIAL
# 1 2020-02-25       3352  21972                  OFFICE     COMMERCIAL
# 2 2022-01-25       2902  21586     HOSPITAL OUTPATIENT       MEDICARE
# 3 2022-03-05       2943   2439              UNASSIGNED     COMMERCIAL
# 4 2018-01-03       3589   6381                  OFFICE       MEDICARE
#
#      TXN_TYPE           TXN_DESC
# 0    SYMPTOMS  ACUTE_PHARYNGITIS
# 1  CONDITIONS            OBESITY
# 2  CONDITIONS  IMMUNOCOMPROMISED
# 3  CONDITIONS           DIABETES
# 4    SYMPTOMS              COUGH
# Data from dim_patient.csv:
#   PATIENT_ID    BIRTH_DT  PATIENT_AGE PATIENT_GENDER
# 0          1  1988-01-01           36         M-Male
# 1          2  2020-01-01            4         M-Male
# 2          3  1973-01-01           51         M-Male
# 3          4  2022-01-01            2         M-Male
# 4          5  1988-01-01           36         M-Male

# %%
# Create a dataframe from the dataframes dictionary
dim_patient = dataframes['dim_patient.csv']
dim_physician = dataframes['dim_physician.csv']
fact_txn = dataframes['fact_txn.csv']

# %%
# Calculate num conditions from fact_txn table

fact_txn_num_conditions = fact_txn.groupby('PATIENT_ID')['TXN_TYPE'].apply(lambda x: (x == 'CONDITIONS').sum()).reset_index(name='NUM_CONDITIONS')
print(fact_txn_num_conditions)
# Out:
#      PATIENT_ID  NUM_CONDITIONS
# 0             1               1
# 1            10               1
# 2           100               1
# 3          1000               5
# 4          1001              20
# ...         ...             ...
# 4015        995               1
# 4016        996               2
# 4017        997              18
# 4018        998               3
# 4019        999              24
#
# [4020 rows x 2 columns]

# %%
# Testing
display(fact_txn_num_conditions[fact_txn_num_conditions['PATIENT_ID'] == '4017'])
# Out:
#      PATIENT_ID  NUM_CONDITIONS
# 3354       4017              64

# %%
display(fact_txn_num_conditions[fact_txn_num_conditions['PATIENT_ID'] == '3476'])
# Out:
#      PATIENT_ID  NUM_CONDITIONS
# 2752       3476               9

# %%
# Calculate num contraindications from fact_txn table

fact_txn_num_contraindications = fact_txn.groupby('PATIENT_ID')['TXN_TYPE'].apply(lambda x: (x == 'CONTRAINDICATIONS').sum()).reset_index(name='NUM_CONTRAINDICATIONS')
fact_txn_num_contraindications
# Out:
#      PATIENT_ID  NUM_CONTRAINDICATIONS
# 0             1                      0
# 1            10                      0
# 2           100                      0
# 3          1000                      0
# 4          1001                      3
# ...         ...                    ...
# 4015        995                      0
# 4016        996                      0
# 4017        997                      0
# 4018        998                      0
# 4019        999                      1
#
# [4020 rows x 2 columns]

# %%
# Calculate num symptoms from fact_txn table

fact_txn_num_symptoms = fact_txn.groupby('PATIENT_ID')['TXN_TYPE'].apply(lambda x: (x == 'SYMPTOMS').sum()).reset_index(name='NUM_SYMPTOMS')
print(fact_txn_num_symptoms)
# Out:
#      PATIENT_ID  NUM_SYMPTOMS
# 0             1             0
# 1            10             0
# 2           100             1
# 3          1000            16
# 4          1001             5
# ...         ...           ...
# 4015        995             3
# 4016        996            13
# 4017        997            12
# 4018        998             6
# 4019        999            18
#
# [4020 rows x 2 columns]

# %%
# Calculate target (Drug A patients)
fact_txn_treatment= fact_txn.groupby('PATIENT_ID')['TXN_DESC'].apply(lambda x: (x == 'DRUG A').sum()).reset_index(name='DRUGA_COUNT')
fact_txn_treatment.head(100)
# Out:
#    PATIENT_ID  DRUGA_COUNT
# 0           1            0
# 1          10            0
# 2         100            0
# 3        1000            0
# 4        1001            0
# ..        ...          ...
# 95       1084            0
# 96       1085            0
# 97       1086            0
# 98       1087            0
# 99       1088            0
#
# [100 rows x 2 columns]

# %%
display(fact_txn_treatment[fact_txn_treatment['PATIENT_ID'] == '4010'])
# Out:
#      PATIENT_ID  DRUGA_COUNT
# 3347       4010            1

# %%
# Patients that were treated with drug A more than once
fact_txn_treatment.loc[fact_txn_treatment['DRUGA_COUNT'] > 1]
# Out:
#      PATIENT_ID  DRUGA_COUNT
# 651        1585            2
# 1119       2005            2
# 1165       2047            2
# 1875       2687            2
# 3246       3920            2
# 3324       3991            2
# 3690        701            2

# %%
# Now create the boolean (1,0) target column
fact_txn_treatment['TARGET'] = np.where(fact_txn_treatment['DRUGA_COUNT'] >= 1, 1, 0)
fact_txn_treatment.head()
# Out:
#   PATIENT_ID  DRUGA_COUNT  TARGET
# 0          1            0       0
# 1         10            0       0
# 2        100            0       0
# 3       1000            0       0
# 4       1001            0       0

# %%
display(fact_txn_treatment[fact_txn_treatment['PATIENT_ID'] == '701'])
# Out:
#      PATIENT_ID  DRUGA_COUNT  TARGET
# 3690        701            2       1

# %%
# Patients with prescribed with drug a more than once 
fact_txn_treatment.loc[fact_txn_treatment['DRUGA_COUNT'] > 1]
# Out:
#      PATIENT_ID  DRUGA_COUNT  TARGET
# 651        1585            2       1
# 1119       2005            2       1
# 1165       2047            2       1
# 1875       2687            2       1
# 3246       3920            2       1
# 3324       3991            2       1
# 3690        701            2       1

# %%
#disease x diagnosis fact_txn

#create a df grouped by patient ID that counts how many time a patient has been diagnosed with disease x
fact_txn_disease_x = fact_txn.groupby('PATIENT_ID')['TXN_DESC'].apply(lambda x: (x == 'DISEASE_X').sum()).reset_index(name='DISEASEX_COUNT')
print(fact_txn_disease_x)
# Out:
#      PATIENT_ID  DISEASEX_COUNT
# 0             1               1
# 1            10               1
# 2           100               1
# 3          1000               2
# 4          1001               1
# ...         ...             ...
# 4015        995               1
# 4016        996               1
# 4017        997               2
# 4018        998               1
# 4019        999               3
#
# [4020 rows x 2 columns]

# %%
fact_txn_disease_x[fact_txn_disease_x['PATIENT_ID'] == '401']
# Out:
#      PATIENT_ID  DISEASEX_COUNT
# 3346        401              22

# %%
# Patients diagnosed with disease x more than once
fact_txn_disease_x.loc[fact_txn_disease_x['DISEASEX_COUNT'] > 1]
# Out:
#      PATIENT_ID  DISEASEX_COUNT
# 3          1000               2
# 6          1003               2
# 7          1004               2
# 8          1005               2
# 9          1006               4
# ...         ...             ...
# 4004        985               2
# 4008        989               2
# 4009         99               3
# 4017        997               2
# 4019        999               3
#
# [1100 rows x 2 columns]

# %%
#features from first time disease x was diagnosed need to be extracted 

#sort values by date
fact_txn_disease_x_features = fact_txn.sort_values(by='TXN_DT',ascending=True)

#filter by txn_desc == disease x
fact_txn_disease_x_features = fact_txn_disease_x_features[fact_txn_disease_x_features['TXN_DESC'] == 'DISEASE_X']
fact_txn_disease_x_features
# Out:
#            TXN_DT PATIENT_ID HCP_ID       TXN_LOCATION_TYPE INSURANCE_TYPE  \
# 9199   2022-04-01        683  16981              UNASSIGNED       MEDICAID
# 105575 2022-04-03       1176    NaN  INDEPENDENT LABORATORY     COMMERCIAL
# 87097  2022-04-08       2295    NaN  OTHER PLACE OF SERVICE     COMMERCIAL
# 94077  2022-04-08       2509    NaN  OTHER PLACE OF SERVICE     COMMERCIAL
# 65429  2022-04-09       3208  18291    URGENT CARE FACILITY       MEDICARE
# ...           ...        ...    ...                     ...            ...
# 40241  2022-07-22       3604  14536                  OFFICE     COMMERCIAL
# 60809  2022-07-22       1019  15987      INPATIENT HOSPITAL     COMMERCIAL
# 73663  2022-07-22       1590  20531              UNASSIGNED     COMMERCIAL
# 105428 2022-07-22         85  16215      INPATIENT HOSPITAL       MEDICARE
# 22950  2022-07-22       3718    NaN  OTHER PLACE OF SERVICE     COMMERCIAL
#
#           TXN_TYPE   TXN_DESC
# 9199    CONDITIONS  DISEASE_X
# 105575  CONDITIONS  DISEASE_X
# 87097   CONDITIONS  DISEASE_X
# 94077   CONDITIONS  DISEASE_X
# 65429   CONDITIONS  DISEASE_X
# ...            ...        ...
# 40241   CONDITIONS  DISEASE_X
# 60809   CONDITIONS  DISEASE_X
# 73663   CONDITIONS  DISEASE_X
# 105428  CONDITIONS  DISEASE_X
# 22950   CONDITIONS  DISEASE_X
#
# [6900 rows x 7 columns]

# %%
#Create a rank (cumulative sum) of disease x diagnosis per patient, as it is sorted by date rank == 1 shall be the first diagnosis for each patient
fact_txn_disease_x_features['RANK'] = fact_txn_disease_x_features.groupby('PATIENT_ID').cumcount() + 1
fact_txn_disease_x_features.head(30)
# Out:
#            TXN_DT PATIENT_ID HCP_ID  \
# 9199   2022-04-01        683  16981
# 105575 2022-04-03       1176    NaN
# 87097  2022-04-08       2295    NaN
# 94077  2022-04-08       2509    NaN
# 65429  2022-04-09       3208  18291
# 10639  2022-04-10       3208    NaN
# 29216  2022-04-11       3208  15000
# 45121  2022-04-11       3208   1976
# 95936  2022-04-11        189    NaN
# 46362  2022-04-12        401    678
# 68386  2022-04-12        401    678
# 1211   2022-04-13       1585  14889
# 98850  2022-04-13       1585  14889
# 16653  2022-04-13        401    678
# 54060  2022-04-14        401    678
# 65644  2022-04-14       3095  23024
# 20994  2022-04-14       3095   5663
# 4499   2022-04-14       3208  15000
# 44664  2022-04-16        372  10840
# 18480  2022-04-16        372   8484
# 96407  2022-04-18       2785  18891
# 29869  2022-04-19       3095   5663
# 107325 2022-04-19       3095  14548
# 64994  2022-04-20       3208  21136
# 112670 2022-04-20       3208  21136
# 66868  2022-04-20        401   5149
# 21033  2022-04-21       2029    NaN
# 5100   2022-04-21       1127  13251
# 80218  2022-04-21       1090   6855
# 57301  2022-04-22       1034   4447
#
#                                      TXN_LOCATION_TYPE INSURANCE_TYPE  \
# 9199                                        UNASSIGNED       MEDICAID
# 105575                          INDEPENDENT LABORATORY     COMMERCIAL
# 87097                           OTHER PLACE OF SERVICE     COMMERCIAL
# 94077                           OTHER PLACE OF SERVICE     COMMERCIAL
# 65429                             URGENT CARE FACILITY       MEDICARE
# 10639                           INDEPENDENT LABORATORY       MEDICARE
# 29216                             URGENT CARE FACILITY       MEDICARE
# 45121                             URGENT CARE FACILITY       MEDICARE
# 95936                           OTHER PLACE OF SERVICE       MEDICARE
# 46362   HOSPITAL INPATIENT (INCLUDING MEDICARE PART A)     COMMERCIAL
# 68386                               INPATIENT HOSPITAL     COMMERCIAL
# 1211                                            OFFICE     COMMERCIAL
# 98850                              HOSPITAL OUTPATIENT     COMMERCIAL
# 16653                               INPATIENT HOSPITAL     COMMERCIAL
# 54060                               INPATIENT HOSPITAL     COMMERCIAL
# 65644                                       UNASSIGNED     COMMERCIAL
# 20994                                       UNASSIGNED     COMMERCIAL
# 4499                              URGENT CARE FACILITY       MEDICARE
# 44664                    ON CAMPUS-OUTPATIENT HOSPITAL     COMMERCIAL
# 18480                        EMERGENCY ROOM - HOSPITAL     COMMERCIAL
# 96407                                           OFFICE     COMMERCIAL
# 29869                                       UNASSIGNED     COMMERCIAL
# 107325                                      UNASSIGNED     COMMERCIAL
# 64994                              HOSPITAL OUTPATIENT       MEDICARE
# 112670                   ON CAMPUS-OUTPATIENT HOSPITAL       MEDICARE
# 66868                                       UNASSIGNED     COMMERCIAL
# 21033                           INDEPENDENT LABORATORY     COMMERCIAL
# 5100                         EMERGENCY ROOM - HOSPITAL     COMMERCIAL
# 80218                           OTHER PLACE OF SERVICE       MEDICAID
# 57301                                           OFFICE     COMMERCIAL
#
#           TXN_TYPE   TXN_DESC  RANK
# 9199    CONDITIONS  DISEASE_X     1
# 105575  CONDITIONS  DISEASE_X     1
# 87097   CONDITIONS  DISEASE_X     1
# 94077   CONDITIONS  DISEASE_X     1
# 65429   CONDITIONS  DISEASE_X     1
# 10639   CONDITIONS  DISEASE_X     2
# 29216   CONDITIONS  DISEASE_X     3
# 45121   CONDITIONS  DISEASE_X     4
# 95936   CONDITIONS  DISEASE_X     1
# 46362   CONDITIONS  DISEASE_X     1
# 68386   CONDITIONS  DISEASE_X     2
# 1211    CONDITIONS  DISEASE_X     1
# 98850   CONDITIONS  DISEASE_X     2
# 16653   CONDITIONS  DISEASE_X     3
# 54060   CONDITIONS  DISEASE_X     4
# 65644   CONDITIONS  DISEASE_X     1
# 20994   CONDITIONS  DISEASE_X     2
# 4499    CONDITIONS  DISEASE_X     5
# 44664   CONDITIONS  DISEASE_X     1
# 18480   CONDITIONS  DISEASE_X     2
# 96407   CONDITIONS  DISEASE_X     1
# 29869   CONDITIONS  DISEASE_X     3
# 107325  CONDITIONS  DISEASE_X     4
# 64994   CONDITIONS  DISEASE_X     6
# 112670  CONDITIONS  DISEASE_X     7
# 66868   CONDITIONS  DISEASE_X     5
# 21033   CONDITIONS  DISEASE_X     1
# 5100    CONDITIONS  DISEASE_X     1
# 80218   CONDITIONS  DISEASE_X     1
# 57301   CONDITIONS  DISEASE_X     1

# %%
#sort the resulted data frame by patient ID to review 
fact_txn_disease_x_features = fact_txn_disease_x_features.sort_values(by='PATIENT_ID',ascending=True)
fact_txn_disease_x_features.head(30)
# Out:
#            TXN_DT PATIENT_ID HCP_ID  \
# 91556  2022-06-11          1  24633
# 105223 2022-06-01         10  12379
# 79658  2022-06-08        100   3559
# 57246  2022-06-08       1000    NaN
# 16495  2022-06-15       1000    NaN
# 50438  2022-06-10       1001    461
# 80693  2022-06-21       1002    NaN
# 86346  2022-06-18       1003  17146
# 111909 2022-06-20       1003  17146
# 68151  2022-06-10       1004  19500
# 31630  2022-06-15       1004  17561
# 107769 2022-07-06       1005  16863
# 12937  2022-06-21       1005  16863
# 81702  2022-06-16       1006  19002
# 81786  2022-06-18       1006  19002
# 70461  2022-06-17       1006  19002
# 82947  2022-06-15       1006  19002
# 42011  2022-06-29       1007   1850
# 87909  2022-06-08       1008   2885
# 13063  2022-06-30       1009    476
# 11047  2022-06-15        101  13723
# 11048  2022-06-14        101  13723
# 316    2022-06-14        101   3211
# 63762  2022-06-21       1010  16426
# 38301  2022-06-20       1010  16426
# 77268  2022-06-20       1011    NaN
# 104048 2022-06-15       1011    NaN
# 113875 2022-06-02       1012   8889
# 36008  2022-06-05       1013  15580
# 7676   2022-06-15       1014   9941
#
#                                        TXN_LOCATION_TYPE INSURANCE_TYPE  \
# 91556                          EMERGENCY ROOM - HOSPITAL     COMMERCIAL
# 105223                         EMERGENCY ROOM - HOSPITAL     COMMERCIAL
# 79658                                             OFFICE     COMMERCIAL
# 57246                             INDEPENDENT LABORATORY     COMMERCIAL
# 16495                             INDEPENDENT LABORATORY     COMMERCIAL
# 50438   TELEHEALTH PROVIDED OTHER THAN IN PATIENT'S HOME     COMMERCIAL
# 80693                             INDEPENDENT LABORATORY       MEDICAID
# 86346                                             OFFICE     COMMERCIAL
# 111909                                            OFFICE     COMMERCIAL
# 68151                               URGENT CARE FACILITY     COMMERCIAL
# 31630                               URGENT CARE FACILITY     COMMERCIAL
# 107769                                            OFFICE     COMMERCIAL
# 12937                                             OFFICE     COMMERCIAL
# 81702                          EMERGENCY ROOM - HOSPITAL     COMMERCIAL
# 81786                                 INPATIENT HOSPITAL     COMMERCIAL
# 70461                                 INPATIENT HOSPITAL     COMMERCIAL
# 82947                          EMERGENCY ROOM - HOSPITAL     COMMERCIAL
# 42011                                             OFFICE     COMMERCIAL
# 87909   TELEHEALTH PROVIDED OTHER THAN IN PATIENT'S HOME     COMMERCIAL
# 13063                  FEDERALLY QUALIFIED HEALTH CENTER     COMMERCIAL
# 11047                          EMERGENCY ROOM - HOSPITAL     COMMERCIAL
# 11048                          EMERGENCY ROOM - HOSPITAL     COMMERCIAL
# 316                            EMERGENCY ROOM - HOSPITAL     COMMERCIAL
# 63762                                HOSPITAL OUTPATIENT     COMMERCIAL
# 38301                                HOSPITAL OUTPATIENT     COMMERCIAL
# 77268                             INDEPENDENT LABORATORY     COMMERCIAL
# 104048                            INDEPENDENT LABORATORY     COMMERCIAL
# 113875                                            OFFICE     COMMERCIAL
# 36008                          EMERGENCY ROOM - HOSPITAL     COMMERCIAL
# 7676                                  INPATIENT HOSPITAL     COMMERCIAL
#
#           TXN_TYPE   TXN_DESC  RANK
# 91556   CONDITIONS  DISEASE_X     1
# 105223  CONDITIONS  DISEASE_X     1
# 79658   CONDITIONS  DISEASE_X     1
# 57246   CONDITIONS  DISEASE_X     1
# 16495   CONDITIONS  DISEASE_X     2
# 50438   CONDITIONS  DISEASE_X     1
# 80693   CONDITIONS  DISEASE_X     1
# 86346   CONDITIONS  DISEASE_X     1
# 111909  CONDITIONS  DISEASE_X     2
# 68151   CONDITIONS  DISEASE_X     1
# 31630   CONDITIONS  DISEASE_X     2
# 107769  CONDITIONS  DISEASE_X     2
# 12937   CONDITIONS  DISEASE_X     1
# 81702   CONDITIONS  DISEASE_X     2
# 81786   CONDITIONS  DISEASE_X     4
# 70461   CONDITIONS  DISEASE_X     3
# 82947   CONDITIONS  DISEASE_X     1
# 42011   CONDITIONS  DISEASE_X     1
# 87909   CONDITIONS  DISEASE_X     1
# 13063   CONDITIONS  DISEASE_X     1
# 11047   CONDITIONS  DISEASE_X     3
# 11048   CONDITIONS  DISEASE_X     2
# 316     CONDITIONS  DISEASE_X     1
# 63762   CONDITIONS  DISEASE_X     2
# 38301   CONDITIONS  DISEASE_X     1
# 77268   CONDITIONS  DISEASE_X     2
# 104048  CONDITIONS  DISEASE_X     1
# 113875  CONDITIONS  DISEASE_X     1
# 36008   CONDITIONS  DISEASE_X     1
# 7676    CONDITIONS  DISEASE_X     1

# %%
diagnosed_patients_count = fact_txn_disease_x_features['PATIENT_ID'].nunique()
diagnosed_patients_count
# Out:
# 4020

# %%
total_patients_count = fact_txn['PATIENT_ID'].nunique()
total_patients_count
# Out:
# 4020

# %%
fact_txn_disease_x_features[fact_txn_disease_x_features['PATIENT_ID'] == '683']
# Out:
#           TXN_DT PATIENT_ID HCP_ID TXN_LOCATION_TYPE INSURANCE_TYPE  \
# 1832  2022-06-01        683  16981        UNASSIGNED       MEDICAID
# 19723 2022-05-01        683  16981        UNASSIGNED       MEDICAID
# 9199  2022-04-01        683  16981        UNASSIGNED       MEDICAID
#
#          TXN_TYPE   TXN_DESC  RANK
# 1832   CONDITIONS  DISEASE_X     3
# 19723  CONDITIONS  DISEASE_X     2
# 9199   CONDITIONS  DISEASE_X     1

# %%
#remove rows for ranks > 1 
fact_txn_disease_x_features = fact_txn_disease_x_features.loc[fact_txn_disease_x_features['RANK'] == 1]
fact_txn_disease_x_features.head(30)
# Out:
#            TXN_DT PATIENT_ID HCP_ID  \
# 91556  2022-06-11          1  24633
# 105223 2022-06-01         10  12379
# 79658  2022-06-08        100   3559
# 57246  2022-06-08       1000    NaN
# 50438  2022-06-10       1001    461
# 80693  2022-06-21       1002    NaN
# 86346  2022-06-18       1003  17146
# 68151  2022-06-10       1004  19500
# 12937  2022-06-21       1005  16863
# 82947  2022-06-15       1006  19002
# 42011  2022-06-29       1007   1850
# 87909  2022-06-08       1008   2885
# 13063  2022-06-30       1009    476
# 316    2022-06-14        101   3211
# 38301  2022-06-20       1010  16426
# 104048 2022-06-15       1011    NaN
# 113875 2022-06-02       1012   8889
# 36008  2022-06-05       1013  15580
# 7676   2022-06-15       1014   9941
# 52546  2022-06-23       1015  17334
# 92206  2022-06-28       1016   1094
# 91870  2022-06-11       1017  22680
# 77405  2022-06-27       1018   3494
# 96360  2022-06-27       1019   3885
# 59670  2022-06-18        102  10961
# 7233   2022-06-16       1020  14453
# 57465  2022-06-07       1021   6585
# 14534  2022-06-26       1022  12784
# 12916  2022-06-15       1023  22948
# 102682 2022-06-01       1024   2910
#
#                                        TXN_LOCATION_TYPE INSURANCE_TYPE  \
# 91556                          EMERGENCY ROOM - HOSPITAL     COMMERCIAL
# 105223                         EMERGENCY ROOM - HOSPITAL     COMMERCIAL
# 79658                                             OFFICE     COMMERCIAL
# 57246                             INDEPENDENT LABORATORY     COMMERCIAL
# 50438   TELEHEALTH PROVIDED OTHER THAN IN PATIENT'S HOME     COMMERCIAL
# 80693                             INDEPENDENT LABORATORY       MEDICAID
# 86346                                             OFFICE     COMMERCIAL
# 68151                               URGENT CARE FACILITY     COMMERCIAL
# 12937                                             OFFICE     COMMERCIAL
# 82947                          EMERGENCY ROOM - HOSPITAL     COMMERCIAL
# 42011                                             OFFICE     COMMERCIAL
# 87909   TELEHEALTH PROVIDED OTHER THAN IN PATIENT'S HOME     COMMERCIAL
# 13063                  FEDERALLY QUALIFIED HEALTH CENTER     COMMERCIAL
# 316                            EMERGENCY ROOM - HOSPITAL     COMMERCIAL
# 38301                                HOSPITAL OUTPATIENT     COMMERCIAL
# 104048                            INDEPENDENT LABORATORY     COMMERCIAL
# 113875                                            OFFICE     COMMERCIAL
# 36008                          EMERGENCY ROOM - HOSPITAL     COMMERCIAL
# 7676                                  INPATIENT HOSPITAL     COMMERCIAL
# 52546   TELEHEALTH PROVIDED OTHER THAN IN PATIENT'S HOME     COMMERCIAL
# 92206                               URGENT CARE FACILITY     COMMERCIAL
# 91870                          EMERGENCY ROOM - HOSPITAL     COMMERCIAL
# 77405                               URGENT CARE FACILITY     COMMERCIAL
# 96360                          EMERGENCY ROOM - HOSPITAL     COMMERCIAL
# 59670                               URGENT CARE FACILITY     COMMERCIAL
# 7233                                 HOSPITAL OUTPATIENT     COMMERCIAL
# 57465                                             OFFICE     COMMERCIAL
# 14534                               URGENT CARE FACILITY     COMMERCIAL
# 12916                                             OFFICE     COMMERCIAL
# 102682                              URGENT CARE FACILITY     COMMERCIAL
#
#           TXN_TYPE   TXN_DESC  RANK
# 91556   CONDITIONS  DISEASE_X     1
# 105223  CONDITIONS  DISEASE_X     1
# 79658   CONDITIONS  DISEASE_X     1
# 57246   CONDITIONS  DISEASE_X     1
# 50438   CONDITIONS  DISEASE_X     1
# 80693   CONDITIONS  DISEASE_X     1
# 86346   CONDITIONS  DISEASE_X     1
# 68151   CONDITIONS  DISEASE_X     1
# 12937   CONDITIONS  DISEASE_X     1
# 82947   CONDITIONS  DISEASE_X     1
# 42011   CONDITIONS  DISEASE_X     1
# 87909   CONDITIONS  DISEASE_X     1
# 13063   CONDITIONS  DISEASE_X     1
# 316     CONDITIONS  DISEASE_X     1
# 38301   CONDITIONS  DISEASE_X     1
# 104048  CONDITIONS  DISEASE_X     1
# 113875  CONDITIONS  DISEASE_X     1
# 36008   CONDITIONS  DISEASE_X     1
# 7676    CONDITIONS  DISEASE_X     1
# 52546   CONDITIONS  DISEASE_X     1
# 92206   CONDITIONS  DISEASE_X     1
# 91870   CONDITIONS  DISEASE_X     1
# 77405   CONDITIONS  DISEASE_X     1
# 96360   CONDITIONS  DISEASE_X     1
# 59670   CONDITIONS  DISEASE_X     1
# 7233    CONDITIONS  DISEASE_X     1
# 57465   CONDITIONS  DISEASE_X     1
# 14534   CONDITIONS  DISEASE_X     1
# 12916   CONDITIONS  DISEASE_X     1
# 102682  CONDITIONS  DISEASE_X     1

# %%
print(fact_txn_disease_x_features['PATIENT_ID'].nunique())
print(fact_txn_disease_x_features['PATIENT_ID'].count())
# Out:
# 4020
# 4020

# %%
fact_txn_highcont = fact_txn.groupby('PATIENT_ID')['TXN_DESC'].apply(lambda x: (x == 'HIGH_CONTRAINDICATION').sum()).reset_index(name='HIGHCONT_COUNT')
fact_txn_highcont.loc[fact_txn_highcont['HIGHCONT_COUNT'] > 1]
# Out:
#      PATIENT_ID  HIGHCONT_COUNT
# 269        1240              48
# 444        1399               2
# 462        1414               5
# 654        1588               6
# 680        1610               4
# 792        1711              24
# 857        1770              20
# 893        1802              22
# 1109       1998              18
# 1115       2001               5
# 1303       2171               5
# 1332       2198              22
# 1426       2282               4
# 1462       2314              50
# 1669       2500               4
# 1785       2605               5
# 1999       2799              12
# 2161       2944              24
# 2297       3066              31
# 2398       3157              31
# 2452       3205               9
# 2461       3213              18
# 2660       3393               2
# 2714       3441               4
# 2883       3594              25
# 2891       3600              28
# 3114       3801               3
# 3168       3850              48
# 3190       3870              12
# 3356       4019              31
# 3581        603               2
# 3624        642               3
# 3785        788              39
# 3786        789              47
# 3955        940               3

# %%
fact_txn_medcont = fact_txn.groupby('PATIENT_ID')['TXN_DESC'].apply(lambda x: (x == 'MEDIUM_CONTRAINDICATION').sum()).reset_index(name='MEDCONT_COUNT')
fact_txn_medcont.loc[fact_txn_medcont['MEDCONT_COUNT'] > 1]
# Out:
#      PATIENT_ID  MEDCONT_COUNT
# 8          1005             20
# 127        1112             11
# 165        1147             10
# 237        1211             12
# 277        1248              9
# ...         ...            ...
# 3928        916             38
# 3945        931             20
# 3982        965             15
# 4003        984             20
# 4010        990              4
#
# [253 rows x 2 columns]

# %%
fact_txn_lowcont = fact_txn.groupby('PATIENT_ID')['TXN_DESC'].apply(lambda x: (x == 'LOW_CONTRAINDICATION').sum()).reset_index(name='LOWCONT_COUNT')
fact_txn_lowcont.loc[fact_txn_lowcont['LOWCONT_COUNT'] > 1]
# Out:
#      PATIENT_ID  LOWCONT_COUNT
# 4          1001              3
# 7          1004              6
# 9          1006              2
# 34         1029              8
# 44         1038              2
# ...         ...            ...
# 3971        955              4
# 3974        958              3
# 3986        969              2
# 4002        983             17
# 4003        984              7
#
# [673 rows x 2 columns]

# %%
# Define the directory to save the features
features_directory = '../../data/features'

# Ensure the directory exists
os.makedirs(features_directory, exist_ok=True)

# List of dataframes to save
dfs_to_save = {
    'grp_txn_lowcont': fact_txn_lowcont,
    'grp_txn_medcont': fact_txn_medcont,
    'grp_txn_highcont': fact_txn_highcont,
    'grp_txn_num_conditions': fact_txn_num_conditions,
    'grp_txn_num_contraindications': fact_txn_num_contraindications,
    'grp_txn_num_symptoms': fact_txn_num_symptoms,
    'grp_txn_treatment': fact_txn_treatment,
    'dim_patient': dim_patient,
    'dim_physician': dim_physician,
    'grp_txn_disease_x_features': fact_txn_disease_x_features
}

# Save each dataframe as a CSV file
for name, df in dfs_to_save.items():
    file_path = os.path.join(features_directory, f'{name}.csv')
    df.to_csv(file_path, index=False)
